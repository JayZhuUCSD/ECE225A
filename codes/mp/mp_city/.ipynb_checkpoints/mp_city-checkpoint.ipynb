# %%
def mp_cr(fname1='CA_Cities/CA_Cities.shp',fname2='mp_gc.csv'):
    import geopandas as gpd
    import pandas as pd
    import numpy as np
    gdf = gpd.read_file(fname1)
    df2 = pd.read_csv(fname2)
    df2['CR'] = df2['Crime_PTP']
    mp_dict = dict(zip(df2['City'], df2['CR']))
    
    for index1, row1 in gdf.iterrows():
        if row1['NAME'] in mp_dict.keys():
            gdf.loc[index1, 'CR'] = mp_dict[row1['NAME']] 
        else:
            gdf.loc[index1, 'CR'] = 0
    
    for index2, row2 in gdf.iterrows():
        if gdf.loc[index2, 'CR'] == 0 or np.isnan(gdf.loc[index2, 'CR']):
            gdf.loc[index2, 'Cmap'] = 0
        if gdf.loc[index2, 'CR']>0 and gdf.loc[index2, 'CR']<=70:
            for i in range(7):    
                if gdf.loc[index2, 'CR']>i*10 and gdf.loc[index2, 'CR']<=(i+1)*10:
                    gdf.loc[index2, 'Cmap'] = i+1
        if gdf.loc[index2, 'CR']>70:
             gdf.loc[index2, 'Cmap'] = 8

    gdf.to_file('CA_Cities/CA_Cities.shp')

mp_cr(fname1='CA_Cities/CA_Cities.shp',fname2='mp_gc.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/geopandas/io/file.py:108: FionaDeprecationWarning: Use fiona.Env() instead.
#   with fiona.drivers():

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import geopandas as gpd
gdf1 = gpd.read_file('CA_Places/CA_Places.shp')
gdf2 = gpd.read_file('CA_Cities/CA_Cities.shp')

# %%
# gdf1.columns
# gdf1.head()
# gdf2.columns
# gdf2.head()
f, ax = plt.subplots(1,figsize=(8, 8))
ax = gdf2.plot(axes=ax, alpha=1, column='Cmap', cmap='OrRd')
f.suptitle('California Crime Rate Statistical Map (cases/ year/ thousand people)')
# ax.set_axis_off()
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/geopandas/plotting.py:389: FutureWarning: 'axes' is deprecated, please use 'ax' instead (for consistency with pandas)
#   "(for consistency with pandas)", FutureWarning)
